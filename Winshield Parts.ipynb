# %%
#import libraries

import os
import numpy as np
import pandas as pd
import psycopg2

# %%
path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\Automatic_Distributors_WindShield_Parts.csv"
df = pd.read_csv(path)
df.head(10)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'XVZ1300TF Royal Star Venture',
'XVZ1300TFM Royal Star Midnight Venture',
'VT480 Venture XL',
'VT480TR Venture TR',
'VT500 Venture 500',
'VT500XL Venture 500 XL',
'VT600 Venture 600',
'VT700 Venture 700',
'WVT1100 WaveVenture 1100',
'WVT760 WaveVenture 760',
'WVT700 WaveVenture 700',
'XL700A WaveVenture XL700',
'PZ50GT Phazer GT',
'RS90GT Vector GT',
'RX10GT Apex GT',
'RXW10GT Attack GT',
'RSG90GT RS Rage GT',
'RST90GT RS Venture GT'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 1999))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2007.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'XVZ1300TF Royal Star Venture',
'XVZ1300TFM Royal Star Midnight Venture',
'VT480 Venture XL',
'VT480TR Venture TR',
'VT500 Venture 500',
'VT500XL Venture 500 XL',
'VT600 Venture 600',
'VT700 Venture 700',
'WVT1100 WaveVenture 1100',
'WVT760 WaveVenture 760',
'WVT700 WaveVenture 700',
'XL700A WaveVenture XL700',
'PZ50GT Phazer GT',
'RS90GT Vector GT',
'RX10GT Apex GT',
'RXW10GT Attack GT',
'RSG90GT RS Rage GT',
'RST90GT RS Venture GT'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(1997, 1999))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2007B.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VT500 Venture 500',
'VT500XL Venture 500 XL'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2002))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997_2001.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VT600 Venture 600'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997_2004.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VT700 Venture 700',
'WVT760 WaveVenture 760',
'WVT700 WaveVenture 700'

]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997_2004_Venture700.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'XVZ1300AL Royal Star Boulevard',
'XVZ1300AT Royal Star Tour Classic',
'XVZ1300CT Royal Star Tour Deluxe',
'XVZ1300TF Royal Star Venture',
'XVZ1300TFM Royal Star Midnight Venture',
'RST90 RS Venture',
'XVZ1300TFS Royal Star Venture S'



]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2005_2011_VentureRS.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'PZ50VT Venture Lite'



]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2007_2010_VentureLite.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'VT500 Venture 500',
'VT500XL Venture 500 XL'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(1997, 2002))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997-2001_ven500.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'VT600 Venture 600'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(1997, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997-2003_ven600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'VT700 Venture 700',
'WVT760 WaveVenture 760',
'WVT700 WaveVenture 700'

]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(1998, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_1997-2003_ven700.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'XVZ1300AL Royal Star Boulevard',
'XVZ1300AT Royal Star Tour Classic',
'XVZ1300CT Royal Star Tour Deluxe',
'XVZ1300TF Royal Star Venture',
'XVZ1300TFM Royal Star Midnight Venture',
'RST90 RS Venture',
'XVZ1300TFS Royal Star Venture S'

]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(2005, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2005-2011_venRS.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'PZ50VT Venture Lite',
'PZ50MT Phazer Mountain Lite'

]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(2007, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2007-2011_venlite.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VX500 VMAX 500',
'VX500SX VMAX 500 SX',
'VX500XT VMAX 500 XT',
'VX500XTC VMAX 500 XTC',
'VX500XTCD VMAX 500 XTC Deluxe',
'VX500XTR VMAX 500 XTR',
'VX500DX VMAX 500 Deluxe'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2002))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_97-01_vmax500.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'MM600 Mountain Max 600',
'MM700 Mountain Max 700'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_97-03_mmax600700.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VX600 VMAX 600',
'VX600DX VMAX 600 Deluxe',
'VX600DX VMAX 600 Deluxe',
'VX600SX VMAX 600 SX',
'VX600SX VMAX 600 SX',
'VX600SXS VMAX 600 SXS',
'VX600XT VMAX 600 XT',
'VX600XT VMAX 600 XT',
'VX600XTC VMAX 600 XTC',
'VX600XTC VMAX 600 XTC',
'VX600XTCD VMAX 600 XTC Deluxe',
'VX600XTR VMAX 600 XTR',
'VX600 VMAX 600',
'VX600SX VMAX 600 SX',
'VX600XTC VMAX 600 XTC (Reverse)'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1997, 2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_97-03_vmax600.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'PZ480 Phazer SS',
'PZ480E Phazer SS Electric',
'PZ480ST Phazer Mountain Lite',
'PZ500 Phazer 500',
'PZ500DX Phazer Deluxe',
'PZ500ML Phazer Mountain Lite'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(1999, 2002))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_99-02_phazer.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RX10S RX-1 LE',
'RX10RS RX-1 ER LE',
'RX10R RX-1 ER',
'RX10MS RX-1 Mountain LE',
'RX10M RX-1 Mountain',
'RX10 RX-1'
]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2003, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_03-06_RX-1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RXW10 RX Warrior', 
    'RXW10S RX Warrior LE'

]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2004, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_04-05_RXWARRIOR.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RSG90 RS Rage',
'RSG90GT RS Rage GT'


]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-07RAGE.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RS90K RS Vector',
'RS90GTA RS Vector 40th Anniv',
'RS90LTGT RS Vector LTX GT',
'RS90M RS Vector Mountain',
'RS90MS RS Vector Mountain SE',
'RST90 RS Venture',
'RS90R RS Vector ER',
'RS90 RS Vector',
'RST90GT RS Venture GT',
'RS90LTGT RS Vector LT GT',
'RS90LT RS Vector LTX',
'RS10 RS Venture TF',
'RST90TF RS Venture TF',
'RST90TFY RS Venture TF BAT',
'RST90TFL RS Venture TF LE',
'RS90XT RS Vector XTX',
'RS90XT75 RS Vector XTX 1.75',
'RS90XTL RS Vector XTX 1.75 LE',
'RS90L RS Vector LE',
'RST1NTF RS Venture TF',
'RST1NTF RS Venture TF BAT',
'RS10 RS Vector'


]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-11RSVECTOR.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RST90 RS Venture',
'RST90GT RS Venture GT',
'RS10 RS Venture TF',
'RST90TF RS Venture TF',
'RST90TFY RS Venture TF BAT',
'RST90TFL RS Venture TF LE',
'RST1NTF RS Venture TF',
'RST1NTF RS Venture TF BAT'


]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-11RSVENTURE.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RXW10 Attack',
'RXW10GT Attack GT'



]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-08ATTACJ.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RS90M RS Vector Mountain',
'RS90MS RS Vector Mountain SE'




]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2005, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-08VECTORMTN.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'FX10MTRA FX Nytro MTX 40th Anniv',
'FX10MTR FX Nytro MX',
'FX10MT FX Nytro MTX',
'FX10RTRA FX Nytro RTX 40th Anniv',
'FX10RTR FX Nytro RTX',
'FX10RT FX Nytro RTX Non-Reverse',
'FX10 FX Nytro',
'RS90N Nytro',
'RS90NR Nytro ER',
'FX10RTRS FX Nytro RTX SE',
'FX10XT FX Nytro XTX',
'FX10M FX Nytro MTX SE 162',
'FX10M FX Nytro MTX SE 153',
'FX10M FX Nytro MTX 153',
'FX10XT FX Nytro XTX 1.75',
'FX10M FX Nytro MTX 162'



]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2006, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-11NYTRO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'VK10F VK Professional II',
'VK10F VK Professional II EPS'




]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2007, 2011))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#      Make                         Model Vendor     MPN AD Item Number  \
# 0  YAMAHA      VK10F VK Professional II   NACH  06-183       62-06004
# 1  YAMAHA  VK10F VK Professional II EPS   NACH  06-183       62-06004
# 2  YAMAHA      VK10F VK Professional II   NACH  06-183       62-06004
# 3  YAMAHA  VK10F VK Professional II EPS   NACH  06-183       62-06004
# 4  YAMAHA      VK10F VK Professional II   NACH  06-183       62-06004
# 5  YAMAHA  VK10F VK Professional II EPS   NACH  06-183       62-06004
# 6  YAMAHA      VK10F VK Professional II   NACH  06-183       62-06004
# 7  YAMAHA  VK10F VK Professional II EPS   NACH  06-183       62-06004
#
#                            Vendor Notes     NI#  REF#            OEM#  Year
# 0  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 1  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 2  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2008
# 3  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2008
# 4  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2009
# 5  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2009
# 6  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2010
# 7  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2010

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-11VKPRO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'RX10GT Apex GT',
'RX10RT Apex RTX',
'RX10RTR Apex RTX ER',
'RX10R Apex ER',
'RX10MT Apex MTX',
'RX10MTA Apex MTX SE 40th Anniv',
'RX10MS Apex Mountain SE',
'RX10M Apex Mountain',
'RX10LT Apex LTX',
'RX10GTA Apex GT 40th Anniv',
'RX10LTGTA Apex LTX GT 40th Anniv',
'RX10 Apex',
'RX10LTGT Apex LTX GT',
'RX10PS Apex SE',
'RX10XT Apex XTX',
'RX10XT75 Apex XTX 1.75',
'RX10XTL Apex XTX 1.75 LE',
'RX10L Apex LE',
'RX10L Apex LE 50th'




]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2007, 2013))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                     Model Vendor     MPN AD Item Number  \
# 0    YAMAHA            RX10GT Apex GT   NACH  06-183       62-06004
# 1    YAMAHA           RX10RT Apex RTX   NACH  06-183       62-06004
# 2    YAMAHA       RX10RTR Apex RTX ER   NACH  06-183       62-06004
# 3    YAMAHA             RX10R Apex ER   NACH  06-183       62-06004
# 4    YAMAHA           RX10MT Apex MTX   NACH  06-183       62-06004
# ..      ...                       ...    ...     ...            ...
# 109  YAMAHA           RX10XT Apex XTX   NACH  06-183       62-06004
# 110  YAMAHA    RX10XT75 Apex XTX 1.75   NACH  06-183       62-06004
# 111  YAMAHA  RX10XTL Apex XTX 1.75 LE   NACH  06-183       62-06004
# 112  YAMAHA             RX10L Apex LE   NACH  06-183       62-06004
# 113  YAMAHA        RX10L Apex LE 50th   NACH  06-183       62-06004
#
#                              Vendor Notes     NI#  REF#            OEM#  Year
# 0    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 1    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 2    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 3    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 4    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# ..                                    ...     ...   ...             ...   ...
# 109  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2012
# 110  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2012
# 111  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2012
# 112  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2012
# 113  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2012
#
# [114 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_05-13APEX.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90150-05024-00']}

# List of models
new_list_models = [
'PZ480 Phazer',
'PZ480 Phazer II',
'PZ480 Phazer SS',
'PZ480E Phazer Deluxe',
'PZ480E Phazer E',
'PZ480E Phazer II LE',
'PZ480E Phazer SS Electric',
'PZ480SE Phazer SE',
'PZ480ST Phazer II ST',
'PZ480ST Phazer Mountain Lite',
'PZ50 Phazer',
'PZ500 Phazer 500',
'PZ500DX Phazer Deluxe',
'PZ500ML Phazer Mountain Lite',
'PZ50FX Phazer FX',
'PZ50GT Phazer GT',
'PZ50MT Phazer Mountain Lite',
'PZ50RT Phazer RTX',
'PZ50MT Phazer MTX',
'PZ50XT Phazer XTX',
'FX10MTRA FX Nytro MTX 40th Anniv',
'FX10MTR FX Nytro MX',
'FX10MT FX Nytro MTX',
'FX10RTRA FX Nytro RTX 40th Anniv',
'FX10RTR FX Nytro RTX',
'FX10RT FX Nytro RTX Non-Reverse',
'FX10 FX Nytro',
'RS90N Nytro',
'RS90NR Nytro ER',
'FX10RTRS FX Nytro RTX SE',
'FX10XT FX Nytro XTX',
'FX10M FX Nytro MTX SE 162',
'FX10M FX Nytro MTX SE 153',
'FX10M FX Nytro MTX 153',
'FX10XT FX Nytro XTX 1.75',
'FX10M FX Nytro MTX 162'




]

oem_numbers = ['90150-05024-00']

# Range of years
years = list(range(2007, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                      Model Vendor     MPN AD Item Number  \
# 0    YAMAHA               PZ480 Phazer   NACH  06-183       62-06004
# 1    YAMAHA            PZ480 Phazer II   NACH  06-183       62-06004
# 2    YAMAHA            PZ480 Phazer SS   NACH  06-183       62-06004
# 3    YAMAHA       PZ480E Phazer Deluxe   NACH  06-183       62-06004
# 4    YAMAHA            PZ480E Phazer E   NACH  06-183       62-06004
# ..      ...                        ...    ...     ...            ...
# 175  YAMAHA  FX10M FX Nytro MTX SE 162   NACH  06-183       62-06004
# 176  YAMAHA  FX10M FX Nytro MTX SE 153   NACH  06-183       62-06004
# 177  YAMAHA     FX10M FX Nytro MTX 153   NACH  06-183       62-06004
# 178  YAMAHA   FX10XT FX Nytro XTX 1.75   NACH  06-183       62-06004
# 179  YAMAHA     FX10M FX Nytro MTX 162   NACH  06-183       62-06004
#
#                              Vendor Notes     NI#  REF#            OEM#  Year
# 0    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 1    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 2    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 3    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# 4    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2007
# ..                                    ...     ...   ...             ...   ...
# 175  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2011
# 176  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2011
# 177  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2011
# 178  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2011
# 179  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90150-05024-00  2011
#
# [180 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_07-12PHAZER-NYTRO.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'VX500 VMAX 500',
'VX500ST VMAX 500 ST',
'VX500SX VMAX 500 SX',
'VX500XT VMAX 500 XT',
'VX500XTC VMAX 500 XTC',
'VX500XTCD VMAX 500 XTC Deluxe',
'VX500XTR VMAX 500 XTR',
'VX500DX VMAX 500 Deluxe',
'VX500DX VMAX 500 DX',
'VX700XTCP VMAX 700 XTCP',
'VX700XTCD VMAX 700 XTC Deluxe',
'VX700XTC VMAX 700 XTC',
'VX700XT VMAX 700 XT',
'VX700SXS VMAX 700 SXS',
'VX700SX VMAX 700 SX',
'VX700DX VMAX 700 Deluxe',
'VX700ER VMAX 700 ER',
'VX700 VMAX 700'




]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(2007, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make                    Model Vendor     MPN AD Item Number  \
# 0   YAMAHA           VX500 VMAX 500   NACH  06-183       62-06004
# 1   YAMAHA      VX500ST VMAX 500 ST   NACH  06-183       62-06004
# 2   YAMAHA      VX500SX VMAX 500 SX   NACH  06-183       62-06004
# 3   YAMAHA      VX500XT VMAX 500 XT   NACH  06-183       62-06004
# 4   YAMAHA    VX500XTC VMAX 500 XTC   NACH  06-183       62-06004
# ..     ...                      ...    ...     ...            ...
# 85  YAMAHA    VX700SXS VMAX 700 SXS   NACH  06-183       62-06004
# 86  YAMAHA      VX700SX VMAX 700 SX   NACH  06-183       62-06004
# 87  YAMAHA  VX700DX VMAX 700 Deluxe   NACH  06-183       62-06004
# 88  YAMAHA      VX700ER VMAX 700 ER   NACH  06-183       62-06004
# 89  YAMAHA           VX700 VMAX 700   NACH  06-183       62-06004
#
#                             Vendor Notes     NI#  REF#            OEM#  Year
# 0   3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 1   3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 2   3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 3   3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 4   3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# ..                                   ...     ...   ...             ...   ...
# 85  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 86  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 87  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 88  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 89  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
#
# [90 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_97-02VMX500700.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'VX600 VMAX 600',
'VX600DX VMAX 600 Deluxe',
'VX600DX VMAX 600 DX',
'VX600ER VMAX 600 ER',
'VX600E VMAX 600 LE',
'VX600ST VMAX 600 ST',
'VX600SX VMAX 600 SX',
'VX600SXS VMAX 600 SXS',
'VX600XT VMAX 600 XT',
'VX600XTC VMAX 600 XTC',
'VX600XTCD VMAX 600 XTC Deluxe',
'VX600XTR VMAX 600 XTR',
'VX600XTW VMAX 600 XT Proaction Plus',
'VX600ST VMAX 600 Mountain Max',
'VX600XTC VMAX 600 XTC (Reverse)',
'MM600 Mountain Max 600',
'MM700 Mountain Max 700',
'MM800 Mountain Max 800',
'MM8 Mountain Max LE 154',
'MM8 Mountain Max LE 165',
'MM8 Mountain Max LE 154 SL',
'RST90 RS Venture',
'RST90GT RS Venture GT',
'RS10 RS Venture TF',
'RST90TF RS Venture TF',
'RST90TFY RS Venture TF BAT',
'RST90TFL RS Venture TF LE',
'RST1NTF RS Venture TF',
'RST1NTF RS Venture TF BAT',
'RS90K RS Vector',
'RS90GTA RS Vector 40th Anniv',
'RS90LTGT RS Vector LTX GT',
'RS90M RS Vector Mountain',
'RS90MS RS Vector Mountain SE',
'RS90R RS Vector ER',
'RS90 RS Vector',
'RS90LTGT RS Vector LT GT',
'RS90LT RS Vector LTX',
'RS90XT RS Vector XTX',
'RS90XT75 RS Vector XTX 1.75',
'RS90XTL RS Vector XTX 1.75 LE',
'RS90L RS Vector LE',
'RS10 RS Vector'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(2007, 2012))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                          Model Vendor     MPN AD Item Number  \
# 0    YAMAHA                 VX600 VMAX 600   NACH  06-183       62-06004
# 1    YAMAHA        VX600DX VMAX 600 Deluxe   NACH  06-183       62-06004
# 2    YAMAHA            VX600DX VMAX 600 DX   NACH  06-183       62-06004
# 3    YAMAHA            VX600ER VMAX 600 ER   NACH  06-183       62-06004
# 4    YAMAHA             VX600E VMAX 600 LE   NACH  06-183       62-06004
# ..      ...                            ...    ...     ...            ...
# 210  YAMAHA           RS90XT RS Vector XTX   NACH  06-183       62-06004
# 211  YAMAHA    RS90XT75 RS Vector XTX 1.75   NACH  06-183       62-06004
# 212  YAMAHA  RS90XTL RS Vector XTX 1.75 LE   NACH  06-183       62-06004
# 213  YAMAHA             RS90L RS Vector LE   NACH  06-183       62-06004
# 214  YAMAHA                 RS10 RS Vector   NACH  06-183       62-06004
#
#                              Vendor Notes     NI#  REF#            OEM#  Year
# 0    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 1    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 2    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 3    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 4    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# ..                                    ...     ...   ...             ...   ...
# 210  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 211  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 212  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 213  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
# 214  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2011
#
# [215 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_97-12VMMMRSVENVEC.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'PZ480ST Phazer Mountain Lite',
'PZ50 Phazer',
'PZ500 Phazer 500',
'PZ500DX Phazer Deluxe',
'PZ500ML Phazer Mountain Lite',
'PZ50FX Phazer FX',
'PZ50GT Phazer GT',
'PZ50MT Phazer Mountain Lite',
'PZ50RT Phazer RTX',
'RX10S RX-1 LE',
'RX10RS RX-1 ER LE',
'RX10R RX-1 ER',
'RX10MS RX-1 Mountain LE',
'RX10M RX-1 Mountain',
'RX10 RX-1',
'MM600 Mountain Max 600',
'MM700 Mountain Max 700',
'RS90M RS Vector Mountain',
'RS90MS RS Vector Mountain SE',
'SXV70MH SX Viper Mountain',
'RX10MS Apex Mountain SE',
'RX10M Apex Mountain',
'Mountain Cat 570',
'Mountain Cat 600 EFI',
'Mountain Cat 1000',
'Mountain Cat 500',
'Mountain Cat 500 EFI',
'Mountain Cat 800',
'Mountain Cat 900 144',
'Mountain Cat 900 151',
'Mountain Cat 900 1M',
'Mountain Cat 900 Early Build',
'Mountain Cat 800 EFI LE 144',
'Mountain Cat 800 EFI LE 151',
'Mountain Cat 800 LE 144',
'Mountain Cat 800 LE 151',
'Mountain Cat 600 EFI 136',
'Mountain Cat 600 EFI 144',
'Mountain Cat 600 EFI LE',
'Mountain Cat 600 VEV',
'Mountain Cat 800 EFI',
'Mountain Cat 800 LE',
'Mountain Cat 800 EFI 151',
'Mountain Cat 800 EFI 159',
'Mountain Cat 900 159',
'Mountain Cat 900 EFI 151',
'Mountain Cat 900 EFI 159',
'Mountain Cat 800 EFI 144',
'RXW10 RX Warrior',
'RXW10S RX Warrior LE',
'RSG90 RS Rage',
'RSG90GT RS Rage GT'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(1999, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                         Model Vendor     MPN AD Item Number  \
# 0    YAMAHA  PZ480ST Phazer Mountain Lite   NACH  06-183       62-06004
# 1    YAMAHA                   PZ50 Phazer   NACH  06-183       62-06004
# 2    YAMAHA              PZ500 Phazer 500   NACH  06-183       62-06004
# 3    YAMAHA         PZ500DX Phazer Deluxe   NACH  06-183       62-06004
# 4    YAMAHA  PZ500ML Phazer Mountain Lite   NACH  06-183       62-06004
# ..      ...                           ...    ...     ...            ...
# 463  YAMAHA      Mountain Cat 800 EFI 144   NACH  06-183       62-06004
# 464  YAMAHA              RXW10 RX Warrior   NACH  06-183       62-06004
# 465  YAMAHA          RXW10S RX Warrior LE   NACH  06-183       62-06004
# 466  YAMAHA                 RSG90 RS Rage   NACH  06-183       62-06004
# 467  YAMAHA            RSG90GT RS Rage GT   NACH  06-183       62-06004
#
#                              Vendor Notes     NI#  REF#            OEM#  Year
# 0    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  1999
# 1    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  1999
# 2    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  1999
# 3    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  1999
# 4    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  1999
# ..                                    ...     ...   ...             ...   ...
# 463  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 464  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 465  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 466  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
# 467  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2007
#
# [468 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_99-08phrxmtnrxrage.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['06-183'], 'AD Item Number': ['62-06004'], 
         'Vendor Notes': ['3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD'], 'NI#': ['06-183'], 'REF#': [pd.NA], 'OEM#': ['90179-05523-00']}

# List of models
new_list_models = [
'RXW10 Attack',
'RXW10GT Attack GT',
'RS90M RS Vector Mountain',
'RS90MS RS Vector Mountain SE',
'FX10MTRA FX Nytro MTX 40th Anniv',
'FX10MTR FX Nytro MX',
'FX10MT FX Nytro MTX',
'FX10RTRA FX Nytro RTX 40th Anniv',
'FX10RTR FX Nytro RTX',
'FX10RT FX Nytro RTX Non-Reverse',
'FX10 FX Nytro',
'RS90N Nytro',
'RS90NR Nytro ER',
'FX10RTRS FX Nytro RTX SE',
'FX10XT FX Nytro XTX',
'FX10M FX Nytro MTX SE 162',
'FX10M FX Nytro MTX SE 153',
'FX10M FX Nytro MTX 153',
'FX10XT FX Nytro XTX 1.75',
'FX10M FX Nytro MTX 162',
'VK10 Viking Professional',
'VK540 III',
'RX10GT Apex GT',
'RX10RT Apex RTX',
'RX10RTR Apex RTX ER',
'RX10R Apex ER',
'RX10MT Apex MTX',
'RX10MTA Apex MTX SE 40th Anniv',
'RX10MS Apex Mountain SE',
'RX10M Apex Mountain',
'RX10LT Apex LTX',
'RX10GTA Apex GT 40th Anniv',
'RX10LTGTA Apex LTX GT 40th Anniv',
'RX10 Apex',
'RX10LTGT Apex LTX GT',
'RX10PS Apex SE',
'RX10XT Apex XTX',
'PZ50 Phazer',
'PZ50FX Phazer FX',
'PZ50GT Phazer GT',
'PZ50MT Phazer Mountain Lite',
'PZ50RT Phazer RTX',
'PZ50MT Phazer MTX'
]

oem_numbers = ['90179-05523-00']

# Range of years
years = list(range(2005, 2013))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                             Model Vendor     MPN AD Item Number  \
# 0    YAMAHA                      RXW10 Attack   NACH  06-183       62-06004
# 1    YAMAHA                 RXW10GT Attack GT   NACH  06-183       62-06004
# 2    YAMAHA          RS90M RS Vector Mountain   NACH  06-183       62-06004
# 3    YAMAHA      RS90MS RS Vector Mountain SE   NACH  06-183       62-06004
# 4    YAMAHA  FX10MTRA FX Nytro MTX 40th Anniv   NACH  06-183       62-06004
# ..      ...                               ...    ...     ...            ...
# 339  YAMAHA                  PZ50FX Phazer FX   NACH  06-183       62-06004
# 340  YAMAHA                  PZ50GT Phazer GT   NACH  06-183       62-06004
# 341  YAMAHA       PZ50MT Phazer Mountain Lite   NACH  06-183       62-06004
# 342  YAMAHA                 PZ50RT Phazer RTX   NACH  06-183       62-06004
# 343  YAMAHA                 PZ50MT Phazer MTX   NACH  06-183       62-06004
#
#                              Vendor Notes     NI#  REF#            OEM#  Year
# 0    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2005
# 1    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2005
# 2    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2005
# 3    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2005
# 4    3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2005
# ..                                    ...     ...   ...             ...   ...
# 339  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2012
# 340  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2012
# 341  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2012
# 342  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2012
# 343  3PCS SCREW, 3PCS RUBBER NUT,9.5MM OD  06-183  <NA>  90179-05523-00  2012
#
# [344 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Windshield Parts\MERGE\Yamaha_2005-13phrxmtnrxrage.csv"
final_df.to_csv(file_path, index=False)
